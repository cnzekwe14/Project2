# %%
from pymongo import MongoClient
from pprint import pprint

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo.Olympic_Country_Data

# %%
print(db.list_collection_names())
# Out:
# ['all_olympics']

# %%
all_olympics = db['all_olympics']

pprint(all_olympics.find_one())
# Out:
# {'': 0,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1990)': 142.96,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1991)': 147.525,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1992)': 147.521,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1993)': 147.896,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1994)': 155.669,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1995)': 156.77,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1996)': 154.932,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1997)': 156.444,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1998)': 154.262,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (1999)': 154.416,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (2000)': 152.572,
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19) (2001)': 150.863,
# ...
